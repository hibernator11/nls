# %% [markdown]
# ## Enriching the dataset with geographc locations based on Wikidata and GeoNames

# %%
import pandas as pd #for handling csv and csv contents
from rdflib import Graph, Literal, RDF, URIRef, Namespace #basic RDF handling

# %%
locationPattern = "http://example.org/location/"

# %%
df=pd.read_csv('data/movingImageArchive/MovingImageArchiveGeoNames.csv',sep=",",quotechar='"',dtype={'geonames': str})
print(df)
# Out:
#              Location       lat     long   wikidata geonames
# 0            Aberdeen  57.14369 -2.09814     Q36405  2657832
# 1       Aberdeenshire  57.16667 -2.66667    Q189912  2657830
# 2               Angus  56.66667 -2.91667    Q202177  2657306
# 3         Argyllshire  56.25000 -5.25000    Q652539  2657088
# 4            Ayrshire  55.50000 -4.50000    Q793283  2656700
# 5               Banff  57.66477 -2.52964     Q54809  2656402
# 6        Berwickshire  55.75000 -2.50000    Q786649  2655820
# 7             Borders       NaN      NaN   Q9177476      NaN
# 8                Bute  55.83333 -5.10000   Q1147435  2654168
# 9           Caithness  58.41667 -3.50000    Q864668  2654041
# 10   Clackmannanshire  56.16667 -3.75000    Q207268  2652975
# 11      Dumfriesshire  55.16667 -3.50000   Q1247384  2650795
# 12     Dunbartonshire  56.12639 -4.42069  Q17582129  7280022
# 13             Dundee  56.46913 -2.97489    Q123709  2650752
# 14       East Lothian  55.91667 -2.75000    Q207257  2650386
# 15          Edinburgh  55.95206 -3.19648     Q23436  2650225
# 16               Fife  56.25000 -3.16667    Q201149  2649469
# 17        Forth River  56.04750 -3.70720      Q2421  2649177
# 18            Glasgow  55.86515 -4.25763      Q4093  2648579
# 19       Gorbals, the       NaN      NaN   Q3643362      NaN
# 20     Highlands, the  57.12000 -4.71000    Q106652  2646943
# 21     Inner Hebrides  56.50000 -6.00000     Q81052  2646177
# 22      Invernesshire       NaN      NaN        NaN      NaN
# 23    Kincardineshire  56.91667 -2.50000    Q376914  2645521
# 24        Kinrosshire       NaN      NaN        NaN      NaN
# 25  Kirkudbrightshire       NaN      NaN        NaN      NaN
# 26        Lanarkshire  55.58333 -3.83333    Q530296  2644975
# 27         Midlothian  55.82347 -3.09334    Q206934  2642559
# 28         Morayshire       NaN      NaN   Q1247435      NaN
# 29              Nairn  57.58094 -3.87973    Q980084  2641910
# 30     Orkney Islands  59.00000 -3.00000    Q100166  2640923
# 31     Outer Hebrides  57.75000 -7.00000     Q80967  2640801
# 32     Peebles- shire       NaN      NaN        NaN      NaN
# 33              Perth  56.39522 -3.43139    Q203000  2640358
# 34       Renfrewshire  55.83333 -4.50000    Q211091  2639494
# 35         Ross-shire       NaN      NaN    Q978599      NaN
# 36      Roxburghshire  55.50000 -2.50000    Q664892  2639033
# 37       Selkirkshire  55.50000 -3.00000   Q1247396  2638228
# 38   Shetland Islands  60.33333 -1.33333     Q47134  2638010
# 39           Stirling  56.11903 -3.93682    Q182923  2636910
# 40      Stirlingshire       NaN      NaN   Q1229763      NaN
# 41         Sutherland  58.25000 -4.50000   Q1061313  2636507
# 42       West Lothian  55.91667 -3.50000    Q204940  2634354
# 43       Wigtownshire  54.60000 -4.83333    Q550606  2633928

# %%
g = Graph()

owl = Namespace('http://www.w3.org/2002/07/owl#')
wgs84_pos = Namespace("http://www.w3.org/2003/01/geo/wgs84_pos#")
schema = Namespace("http://schema.org/")
edm = Namespace("http://www.europeana.eu/schemas/edm/")
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
dcterms = Namespace("http://purl.org/dc/terms/")
skos = Namespace("http://www.w3.org/2004/02/skos/core#")

g.bind("owl", owl)
g.bind("wgs84_pos", wgs84_pos)
g.bind("schema", schema)
g.bind("edm", edm)
g.bind("rdfs", rdfs)
g.bind("rdf", rdf)
g.bind("dcterms", dcterms)
g.bind("skos", skos)

# %%
for index, row in df.iterrows():

    # add types
    g.add((URIRef(locationPattern + (row['Location'].lower().replace(" ", ""))), URIRef(rdf+"type"), URIRef(edm + "Place") ))
    g.add((URIRef(locationPattern + row['Location'].lower().replace(" ", "")), URIRef(rdf+'type'), URIRef(schema + "Place") ))
    
    ## add preflabel
    g.add((URIRef(locationPattern + row['Location'].lower().replace(" ", "")), URIRef(skos+'prefLabel'), Literal(row["Location"], "en") ))
    
    ## add lat and long
    g.add((URIRef(locationPattern + row['Location'].lower().replace(" ", "")), URIRef(wgs84_pos+'lat'), Literal(str(row["lat"])) ))
    g.add((URIRef(locationPattern + row['Location'].lower().replace(" ", "")), URIRef(wgs84_pos+'long'), Literal(str(row["long"]))))
    
    if not pd.isnull(row['wikidata']):
        g.add((URIRef(locationPattern + row['Location'].lower().replace(" ", "")), URIRef(owl+'sameAs'), URIRef('https://www.wikidata.org/wiki/' + str(row['wikidata']))))
    if not pd.isnull(row['geonames']):   
        g.add((URIRef(locationPattern + row['Location'].lower().replace(" ", "")), URIRef(owl+'sameAs'), URIRef('https://www.geonames.org/' + str(row['geonames']))))

# %%
print(g.serialize(format='turtle'))

g.serialize('rdf/locations.rdf',format='xml')
# Out:
# @prefix edm: <http://www.europeana.eu/schemas/edm/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix schema: <http://schema.org/> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix wgs84_pos: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
#
# <http://example.org/location/aberdeen> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2657832>,
#         <https://www.wikidata.org/wiki/Q36405> ;
#     wgs84_pos:lat "57.14369" ;
#     wgs84_pos:long "-2.09814" ;
#     skos:prefLabel "Aberdeen"@en .
#
# <http://example.org/location/aberdeenshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2657830>,
#         <https://www.wikidata.org/wiki/Q189912> ;
#     wgs84_pos:lat "57.16667" ;
#     wgs84_pos:long "-2.66667" ;
#     skos:prefLabel "Aberdeenshire"@en .
#
# <http://example.org/location/angus> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2657306>,
#         <https://www.wikidata.org/wiki/Q202177> ;
#     wgs84_pos:lat "56.66667" ;
#     wgs84_pos:long "-2.91667" ;
#     skos:prefLabel "Angus"@en .
#
# <http://example.org/location/argyllshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2657088>,
#         <https://www.wikidata.org/wiki/Q652539> ;
#     wgs84_pos:lat "56.25" ;
#     wgs84_pos:long "-5.25" ;
#     skos:prefLabel "Argyllshire"@en .
#
# <http://example.org/location/ayrshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2656700>,
#         <https://www.wikidata.org/wiki/Q793283> ;
#     wgs84_pos:lat "55.5" ;
#     wgs84_pos:long "-4.5" ;
#     skos:prefLabel "Ayrshire"@en .
#
# <http://example.org/location/banff> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2656402>,
#         <https://www.wikidata.org/wiki/Q54809> ;
#     wgs84_pos:lat "57.66477" ;
#     wgs84_pos:long "-2.52964" ;
#     skos:prefLabel "Banff"@en .
#
# <http://example.org/location/berwickshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2655820>,
#         <https://www.wikidata.org/wiki/Q786649> ;
#     wgs84_pos:lat "55.75" ;
#     wgs84_pos:long "-2.5" ;
#     skos:prefLabel "Berwickshire"@en .
#
# <http://example.org/location/borders> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.wikidata.org/wiki/Q9177476> ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Borders"@en .
#
# <http://example.org/location/bute> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2654168>,
#         <https://www.wikidata.org/wiki/Q1147435> ;
#     wgs84_pos:lat "55.83333" ;
#     wgs84_pos:long "-5.1" ;
#     skos:prefLabel "Bute"@en .
#
# <http://example.org/location/caithness> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2654041>,
#         <https://www.wikidata.org/wiki/Q864668> ;
#     wgs84_pos:lat "58.41667" ;
#     wgs84_pos:long "-3.5" ;
#     skos:prefLabel "Caithness"@en .
#
# <http://example.org/location/clackmannanshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2652975>,
#         <https://www.wikidata.org/wiki/Q207268> ;
#     wgs84_pos:lat "56.16667" ;
#     wgs84_pos:long "-3.75" ;
#     skos:prefLabel "Clackmannanshire"@en .
#
# <http://example.org/location/dumfriesshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2650795>,
#         <https://www.wikidata.org/wiki/Q1247384> ;
#     wgs84_pos:lat "55.16667" ;
#     wgs84_pos:long "-3.5" ;
#     skos:prefLabel "Dumfriesshire"@en .
#
# <http://example.org/location/dunbartonshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/7280022>,
#         <https://www.wikidata.org/wiki/Q17582129> ;
#     wgs84_pos:lat "56.12639" ;
#     wgs84_pos:long "-4.42069" ;
#     skos:prefLabel "Dunbartonshire"@en .
#
# <http://example.org/location/dundee> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2650752>,
#         <https://www.wikidata.org/wiki/Q123709> ;
#     wgs84_pos:lat "56.46913" ;
#     wgs84_pos:long "-2.97489" ;
#     skos:prefLabel "Dundee"@en .
#
# <http://example.org/location/eastlothian> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2650386>,
#         <https://www.wikidata.org/wiki/Q207257> ;
#     wgs84_pos:lat "55.91667" ;
#     wgs84_pos:long "-2.75" ;
#     skos:prefLabel "East Lothian"@en .
#
# <http://example.org/location/edinburgh> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2650225>,
#         <https://www.wikidata.org/wiki/Q23436> ;
#     wgs84_pos:lat "55.95206" ;
#     wgs84_pos:long "-3.19648" ;
#     skos:prefLabel "Edinburgh"@en .
#
# <http://example.org/location/fife> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2649469>,
#         <https://www.wikidata.org/wiki/Q201149> ;
#     wgs84_pos:lat "56.25" ;
#     wgs84_pos:long "-3.16667" ;
#     skos:prefLabel "Fife"@en .
#
# <http://example.org/location/forthriver> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2649177>,
#         <https://www.wikidata.org/wiki/Q2421> ;
#     wgs84_pos:lat "56.0475" ;
#     wgs84_pos:long "-3.7072" ;
#     skos:prefLabel "Forth River"@en .
#
# <http://example.org/location/glasgow> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2648579>,
#         <https://www.wikidata.org/wiki/Q4093> ;
#     wgs84_pos:lat "55.86515" ;
#     wgs84_pos:long "-4.25763" ;
#     skos:prefLabel "Glasgow"@en .
#
# <http://example.org/location/gorbals,the> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.wikidata.org/wiki/Q3643362> ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Gorbals, the"@en .
#
# <http://example.org/location/highlands,the> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2646943>,
#         <https://www.wikidata.org/wiki/Q106652> ;
#     wgs84_pos:lat "57.12" ;
#     wgs84_pos:long "-4.71" ;
#     skos:prefLabel "Highlands, the"@en .
#
# <http://example.org/location/innerhebrides> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2646177>,
#         <https://www.wikidata.org/wiki/Q81052> ;
#     wgs84_pos:lat "56.5" ;
#     wgs84_pos:long "-6.0" ;
#     skos:prefLabel "Inner Hebrides"@en .
#
# <http://example.org/location/invernesshire> a schema:Place,
#         edm:Place ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Invernesshire"@en .
#
# <http://example.org/location/kincardineshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2645521>,
#         <https://www.wikidata.org/wiki/Q376914> ;
#     wgs84_pos:lat "56.91667" ;
#     wgs84_pos:long "-2.5" ;
#     skos:prefLabel "Kincardineshire"@en .
#
# <http://example.org/location/kinrosshire> a schema:Place,
#         edm:Place ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Kinrosshire"@en .
#
# <http://example.org/location/kirkudbrightshire> a schema:Place,
#         edm:Place ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Kirkudbrightshire"@en .
#
# <http://example.org/location/lanarkshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2644975>,
#         <https://www.wikidata.org/wiki/Q530296> ;
#     wgs84_pos:lat "55.58333" ;
#     wgs84_pos:long "-3.83333" ;
#     skos:prefLabel "Lanarkshire"@en .
#
# <http://example.org/location/midlothian> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2642559>,
#         <https://www.wikidata.org/wiki/Q206934> ;
#     wgs84_pos:lat "55.82347" ;
#     wgs84_pos:long "-3.09334" ;
#     skos:prefLabel "Midlothian"@en .
#
# <http://example.org/location/morayshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.wikidata.org/wiki/Q1247435> ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Morayshire"@en .
#
# <http://example.org/location/nairn> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2641910>,
#         <https://www.wikidata.org/wiki/Q980084> ;
#     wgs84_pos:lat "57.58094" ;
#     wgs84_pos:long "-3.87973" ;
#     skos:prefLabel "Nairn"@en .
#
# <http://example.org/location/orkneyislands> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2640923>,
#         <https://www.wikidata.org/wiki/Q100166> ;
#     wgs84_pos:lat "59.0" ;
#     wgs84_pos:long "-3.0" ;
#     skos:prefLabel "Orkney Islands"@en .
#
# <http://example.org/location/outerhebrides> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2640801>,
#         <https://www.wikidata.org/wiki/Q80967> ;
#     wgs84_pos:lat "57.75" ;
#     wgs84_pos:long "-7.0" ;
#     skos:prefLabel "Outer Hebrides"@en .
#
# <http://example.org/location/peebles-shire> a schema:Place,
#         edm:Place ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Peebles- shire"@en .
#
# <http://example.org/location/perth> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2640358>,
#         <https://www.wikidata.org/wiki/Q203000> ;
#     wgs84_pos:lat "56.39522" ;
#     wgs84_pos:long "-3.43139" ;
#     skos:prefLabel "Perth"@en .
#
# <http://example.org/location/renfrewshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2639494>,
#         <https://www.wikidata.org/wiki/Q211091> ;
#     wgs84_pos:lat "55.83333" ;
#     wgs84_pos:long "-4.5" ;
#     skos:prefLabel "Renfrewshire"@en .
#
# <http://example.org/location/ross-shire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.wikidata.org/wiki/Q978599> ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Ross-shire"@en .
#
# <http://example.org/location/roxburghshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2639033>,
#         <https://www.wikidata.org/wiki/Q664892> ;
#     wgs84_pos:lat "55.5" ;
#     wgs84_pos:long "-2.5" ;
#     skos:prefLabel "Roxburghshire"@en .
#
# <http://example.org/location/selkirkshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2638228>,
#         <https://www.wikidata.org/wiki/Q1247396> ;
#     wgs84_pos:lat "55.5" ;
#     wgs84_pos:long "-3.0" ;
#     skos:prefLabel "Selkirkshire"@en .
#
# <http://example.org/location/shetlandislands> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2638010>,
#         <https://www.wikidata.org/wiki/Q47134> ;
#     wgs84_pos:lat "60.33333" ;
#     wgs84_pos:long "-1.33333" ;
#     skos:prefLabel "Shetland Islands"@en .
#
# <http://example.org/location/stirling> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2636910>,
#         <https://www.wikidata.org/wiki/Q182923> ;
#     wgs84_pos:lat "56.11903" ;
#     wgs84_pos:long "-3.93682" ;
#     skos:prefLabel "Stirling"@en .
#
# <http://example.org/location/stirlingshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.wikidata.org/wiki/Q1229763> ;
#     wgs84_pos:lat "nan" ;
#     wgs84_pos:long "nan" ;
#     skos:prefLabel "Stirlingshire"@en .
#
# <http://example.org/location/sutherland> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2636507>,
#         <https://www.wikidata.org/wiki/Q1061313> ;
#     wgs84_pos:lat "58.25" ;
#     wgs84_pos:long "-4.5" ;
#     skos:prefLabel "Sutherland"@en .
#
# <http://example.org/location/westlothian> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2634354>,
#         <https://www.wikidata.org/wiki/Q204940> ;
#     wgs84_pos:lat "55.91667" ;
#     wgs84_pos:long "-3.5" ;
#     skos:prefLabel "West Lothian"@en .
#
# <http://example.org/location/wigtownshire> a schema:Place,
#         edm:Place ;
#     owl:sameAs <https://www.geonames.org/2633928>,
#         <https://www.wikidata.org/wiki/Q550606> ;
#     wgs84_pos:lat "54.6" ;
#     wgs84_pos:long "-4.83333" ;
#     skos:prefLabel "Wigtownshire"@en .
# <Graph identifier=N1f4ea7c06ac14540a064139b1e9e09c0 (<class 'rdflib.graph.Graph'>)>

# %%
g = Graph()
g.parse("rdf/locations.rdf")
g.parse("rdf/movingImageArchive.rdf")
g.serialize('rdf/movingImageArchiveEnriched.rdf',format='xml')
# Out:
# <Graph identifier=N5a83aafdf96f43bb85749582e3ddda70 (<class 'rdflib.graph.Graph'>)>
